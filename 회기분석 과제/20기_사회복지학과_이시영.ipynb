# %% [markdown]
# # 회귀분석 과제
# 2022-01-20
# - 출처 18기 DS 신혜연님
#
# ---
#
# 제출 형식: 본인 Github에 다음과 같은 파일명으로 두 개의 파일을 업로드하시면 됩니다.
# - 20기_학과명_이름.ipynb
# - graduate_submission.csv

# %% [markdown]
# # 목표: 대학원 합격 확률 및 합격 여부 예측
#
# - 회귀: 학습 데이터로 선형 회귀, Ridge, Lasso를 통해 학습시켜 봅시다.
#
# 완성된 모델로 테스트 데이터의 **합격 여부**를 예측해보세요. (합격 여부를 예측하는 것은 분류 문제입니다.)
# 아래의 빈칸(코드+서술 답안)을 모두 채워 넣어주시면 됩니다.
# "## TODO"라고 적힌 부분에는 코드를 작성하여 주시고, "A."라고 적힌 부분에는 서술 답안을 작성하여 주세요.
# 이를 모두 완성한 **(1) ipynb 파일**과 최종 예측을  **(2) csv 파일**로 저장하여 본인 Github에 업로드하시면 됩니다.

# %%
# 패키지 불러오기
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# 경고 무시
import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# # 데이터 로드 및 확인
# graduate_train.csv 파일과 graduate_test.csv 파일을 My Drive에 넣어주세요.
# (Jupyter Notebook을 사용하시는 경우에는 graduate_train.csv 파일과 graduate_test.csv 파일 경로를 각각의 로컬 디렉토리 위치로 변경해주세요.)

# %%
# train 데이터 불러오기
train = pd.read_csv('/Users/siyounglee/Downloads/graduate_train.csv')

# train 데이터 크기 확인
print(train.shape)

# train 데이터 훑어보기
train.head()
# Out:
# (400, 8)
#    GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA Research  \
# 0        310          105                  2  3.0  3.5  8.01       No
# 1        307          105                  2  2.5  4.5  8.12      Yes
# 2        329          111                  4  4.5  4.0  9.01      Yes
# 3        300          105                  1  1.0  2.0  7.80       No
# 4        329          114                  5  4.0  5.0  9.30      Yes
#
#    Chance of Admit
# 0             0.71
# 1             0.67
# 2             0.81
# 3             0.58
# 4             0.86

# %%
# test 데이터 불러오기
test = pd.read_csv('/Users/siyounglee/Downloads/graduate_test.csv')

# test 데이터 크기 확인
print(test.shape)

# test 데이터 훑어보기
test.head()

# test 데이터에는 'Chance of Admit'이 없습니다. 이 확률을 예측해보는 것이 과제입니다.
# Out:
# (100, 7)
#    GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA Research
# 0        304          103                  5  5.0  4.0  8.64       No
# 1        297           96                  2  2.5  1.5  7.89       No
# 2        302          101                  2  2.5  3.5  7.96       No
# 3        318          112                  3  4.0  3.5  8.67       No
# 4        304          100                  4  1.5  2.5  7.84       No

# %% [markdown]
# # 1. 결측치

# %% [markdown]
# 데이터에 결측치가 있는지 확인해보세요.

# %%
## TODO
train.info()
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GRE Score          400 non-null    int64
#  1   TOEFL Score        400 non-null    int64
#  2   University Rating  400 non-null    int64
#  3   SOP                400 non-null    float64
#  4   LOR                400 non-null    float64
#  5   CGPA               400 non-null    float64
#  6   Research           400 non-null    object
#  7   Chance of Admit    400 non-null    float64
# dtypes: float64(4), int64(3), object(1)
# memory usage: 25.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GRE Score          100 non-null    int64
#  1   TOEFL Score        100 non-null    int64
# ...

# %% [markdown]
# Q. 데이터에 결측치가 있나요? 어떤 방법으로 처리하였나요?
# A. .info()를 통해 몇개의 null 값이 있는지만 우선적으로 확인하고자 했는데 확인 결과 null 값은 없었습니다.

# %% [markdown]
# # 2. 범주형 변수

# %% [markdown]
# 설명변수 중 범주형 변수가 존재하나요?
# 존재한다면 어떻게 처리해주어야 할까요?
# **학습 데이터를 수정하는 경우 테스트 데이터도 그에 맞게 수정해주어야 된다는 점에 유의하세요.**

# %%
## TODO
train.dtypes
# Out:
# GRE Score              int64
# TOEFL Score            int64
# University Rating      int64
# SOP                  float64
# LOR                  float64
# CGPA                 float64
# Research              object
# Chance of Admit      float64
# dtype: object

# %%
test = pd.get_dummies(data=test, columns=['Research'])
test.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  Research_No  \
# 0        304          103                  5  5.0  4.0  8.64            1
# 1        297           96                  2  2.5  1.5  7.89            1
# 2        302          101                  2  2.5  3.5  7.96            1
# 3        318          112                  3  4.0  3.5  8.67            1
# 4        304          100                  4  1.5  2.5  7.84            1
#
#    Research_Yes
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %%
train = pd.get_dummies(data=train, columns=['Research'])
train.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  Chance of Admit  \
# 0        310          105                  2  3.0  3.5  8.01             0.71
# 1        307          105                  2  2.5  4.5  8.12             0.67
# 2        329          111                  4  4.5  4.0  9.01             0.81
# 3        300          105                  1  1.0  2.0  7.80             0.58
# 4        329          114                  5  4.0  5.0  9.30             0.86
#
#    Research_No  Research_Yes
# 0            1             0
# 1            0             1
# 2            0             1
# 3            1             0
# 4            0             1

# %% [markdown]
# Q. 어떤 변수가 범주형인가요? 어떻게 처리해 주었나요?
# A. Research가 범주형 변수이므로 pd.get_dummies() 처리해주었습니다.

# %% [markdown]
# # 3. 선형(Linear) 회귀

# %%
# 먼저 데이터를 설명변수와 종속변수로 분리합니다.
X = train.drop('Chance of Admit', axis=1)
y = train['Chance of Admit']

# %%
# 데이터를 train과 test로 분리하여 사용합니다.
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1234)

# %%
# 각각의 크기 확인
print("training predictors size:", X_train.shape)
print("training response size:", y_train.shape)
print("test predictors size:", X_test.shape)
print("test response size:", y_test.shape)
# Out:
# training predictors size: (320, 8)
# training response size: (320,)
# test predictors size: (80, 8)
# test response size: (80,)

# %% [markdown]
# ### 3.1. scikit-learn으로 선형 회귀

# %%
from sklearn.linear_model import LinearRegression

# %%
# 1. 먼저 모델을 만들어 줍니다.
## TODO
linear = LinearRegression()

# 2. 모델을 적합시킵니다.
## TODO
linear.fit(X_train, y_train)

# 3. train 세트와 test 세트에서의 성능을 확인합니다. (이 경우 결정계수 R^2)
## TODO
print("Training R^2: %.2f" % linear.score(X_train, y_train))
# Out:
# Training R^2: 0.83

# %% [markdown]
# #### 3.1.1. 모델의 MSE와 R^2를 구해봅시다.

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
# 4. X_test로 y_pred를 만들어줍니다.
## TODO
y_pred = linear.predict(X_test)

print('MSE: %.4f' % mean_squared_error(y_test, y_pred))
print('Variance score: %.4f' % r2_score(y_test, y_pred))
# Out:
# MSE: 0.0040
# Variance score: 0.7729

# %% [markdown]
# #### 3.1.2. 모델의 절편 계수를 확인해봅시다.

# %%
## TODO
print(linear.intercept_)
# Out:
# -1.241942143701871

# %% [markdown]
# Q. 절편 계수의 의미는 무엇인가요?
# A. 모든 독립변수(X)가 0일 때 결과(Y) 값

# %% [markdown]
# #### 3.1.3. 모델의 기울기 계수를 확인해 보세요.

# %%
## TODO
beta = pd.DataFrame(linear.coef_, index=X.columns, columns=["slope"])
beta.sort_values("slope")
# Out:
#                       slope
# Research_No       -0.013241
# GRE Score          0.001640
# University Rating  0.002748
# TOEFL Score        0.003606
# SOP                0.007253
# Research_Yes       0.013241
# LOR                0.017343
# CGPA               0.112079

# %% [markdown]
# Q. 기울기 계수의 의미는 무엇인가요? 어떤 예측변인이 대학원 합격 확률과 유의미한 관계를 가지고 있으며 이것을 어떻게 해석할 수 있나요?
# A. 기울기 계수는 특정 변수 X의 단위 변화에 따른 Y의 변화입니다. 기울기의 절대값이 클수록 유의미한 결과를 가져오므로 CGPA가 대학원 합격 확률과 가장 유의미한 관계를 가지고 있다고 볼 수 있습니다.

# %% [markdown]
# #### 3.1.4. 연속형 설명변수 중 하나를 골라 종속변수와의 관계를 scatter plot으로 그려 보세요.

# %%
## TODO
sns.scatterplot(x="CGPA", y="Chance of Admit", data=train)
plt.plot()
# Out:
# []

# %% [markdown]
# #### 3.1.5. 범주형 설명변수와 종속변수의 관계를 box plot으로 그려 보세요.

# %%
## TODO
sns.boxplot(X_train['University Rating'],y_train)
# Out:
# <AxesSubplot:xlabel='University Rating', ylabel='Chance of Admit'>

# %% [markdown]
# ### 3.2. StatsModels로 선형 회귀 시행하기

# %%
import statsmodels.api as sm

# %%
## TODO
model = sm.OLS(y_train, X_train)
model.fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:        Chance of Admit   R-squared:                       0.826
# Model:                            OLS   Adj. R-squared:                  0.822
# Method:                 Least Squares   F-statistic:                     211.6
# Date:                Thu, 27 Jan 2022   Prob (F-statistic):          1.99e-114
# Time:                        17:35:09   Log-Likelihood:                 449.18
# No. Observations:                 320   AIC:                            -882.4
# Df Residuals:                     312   BIC:                            -852.2
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %% [markdown]
# Q. R^2와 F-statistic을 고려해 볼 때, 이 모델은 좋은 모델이라고 볼 수 있나요?
# A. R^2 값이 0.826으로 1에 가까운 값을 보이고 있고, F-statistic이 크기는 하지만 p value가 0.05보다 작은 값을 보이고 있기 때문에 좋은 모델이라고 볼 수 있다.

# %% [markdown]
# Q. 계수에 대한 가설 검정 결과를 바탕으로 'University Rating'이 대학원 합격률에 미치는 영향을 어떻게 해석할 수 있을까요?
# A. 'University Rating'의 p value가 0.05를 넘어가기 때문에 영향력이 적다고 볼 수 있습니다.

# %% [markdown]
# # 4. Ridge, Lasso 회귀

# %% [markdown]
# 이번에는 scikit-learn으로 Ridge와 Lasso를 시도해 보세요.
# **가장 적절한 수준의 alpha를 찾아 모델에 적용해 보세요.**
# (힌트: cross-validation을 사용하세요.)
# (참고자료:
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.RidgeCV.html
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LassoCV.html)

# %%
from sklearn.linear_model import RidgeCV

# 1. 먼저 모델을 만들어 줍니다.
## TODO
ridge = RidgeCV(alphas = [0.1, 0.5, 1.0, 5.0, 10.0])

# 2. 모델을 적합시킵니다.
## TODO
ridge.fit(X_train, y_train)

# 3. train 세트와 test 세트에서의 성능을 확인합니다. (이 경우 결정계수 R^2)
## TODO
print('train R^2: %.2f' % ridge.score(X_train, y_train))
print('test R^2: %.2f' % ridge.score(X_test, y_test))
# Out:
# train R^2: 0.83
# test R^2: 0.77

# %%
from sklearn.linear_model import LassoCV

# 1. 먼저 모델을 만들어 줍니다.
## TODO
lasso = LassoCV(alphas = [0.1, 0.5, 1.0, 5.0, 10.0])

# 2. 모델을 적합시킵니다.
## TODO
lasso.fit(X_train, y_train)

# 3. train 세트와 test 세트에서의 성능을 확인합니다. (이 경우 결정계수 R^2)
## TODO
print('train R^2: %.2f' % lasso.score(X_train, y_train))
print('test R^2: %.2f' % lasso.score(X_test, y_test))
# Out:
# train R^2: 0.69
# test R^2: 0.61

# %%
# 예측결과 저장
predict = ridge.predict(test)
test['Chance of Admit'] = predict
test.to_csv('graduate_submission.csv', index = False)
